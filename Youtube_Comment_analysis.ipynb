# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
# %matplotlib inline
import os

# Import functions for data preprocessing & data preparation
from sklearn.preprocessing import LabelEncoder
from sklearn.utils import resample
from sklearn.feature_extraction.text import CountVectorizer
from nltk.sentiment.vader import SentimentIntensityAnalyzer

from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.stem import PorterStemmer, LancasterStemmer
from nltk.stem.snowball import SnowballStemmer
from nltk.corpus import stopwords
from nltk.corpus import wordnet
import string
from string import punctuation
import nltk
import re

# %%
from youtube_comment_scraper_python import *

import pandas as pd

link = input("Youtube links: ")
saved = input("Output name: ")
youtube.open(link)

response = youtube.video_comments()
all_data = []
for i in range(0, 1):
    response = youtube.video_comments()
    data = response['body']
    all_data.extend(data)
df = pd.DataFrame(data)
df.to_csv(saved)
# Out:
# Youtube links: https://youtu.be/m9EX0f6V11Y
# Output name: ms-marvel
# Progress:  66%|██████▋   | 132.6/200 [00:18<00:17,  3.79it/s]
# Progress:  77%|███████▋  | 153.4/200 [00:22<00:10,  4.42it/s]
# Progress:  92%|█████████▏| 184.20000000000002/200 [00:24<00:02,  7.14it/s]
# Progress: 100%|█████████▉| 199.60000000000002/200 [00:26<00:00,  7.26it/s]
# Progress: 212.00000000000003it [00:28,  6.92it/s]
# Progress: 217.60000000000002it [00:30,  5.72it/s]  7.11it/s]
# Progress: 223.40000000000003it [00:32,  4.89it/s]  5.64it/s]
# Progress: 229.00000000000006it [00:34,  4.26it/s],  4.90it/s]
# Progress: 234.80000000000007it [00:36,  3.83it/s],  4.24it/s]
# Progress: 240.60000000000008it [00:38,  3.51it/s],  3.54it/s]
# Progress: 246.20000000000007it [00:40,  3.26it/s],  3.30it/s]
# Progress: 250.60000000000008it [00:43,  2.91it/s],  3.13it/s]
# Progress: 256.20000000000005it [00:45,  2.87it/s],  3.00it/s]
# Progress: 262.00000000000006it [00:47,  2.85it/s],  2.93it/s]
# Progress: 264.80000000000007it [00:49,  2.42it/s],  2.48it/s]
# Progress: 100%|██████████| 200.0/200 [00:30<00:00,  6.45it/s]
# Progress: 322.6000000000001it [00:51,  6.31it/s]

# %%
df.head()
# Out:
#                                              Comment Likes          Time user  \
# 0  It feels a lot like a Disney show instead of a...   17K  8 months ago
# 1  The Weeknd song was too perfect for this trail...     6    3 days ago
# 2  The most Desi thing about Ms. Marvel was when ...  2.5K  5 months ago
# 3  Güzel bir diziye benziyor MS Marvel avengers o...     1    2 days ago
# 4  Kinda bummed they're switching up the powers s...    2K  7 months ago
#
#   UserLink
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN

# %%
data = df
data.columns
data1=data.drop(['Likes','Time','user'],axis=1)
data1
# Out:
#                                               Comment  \
# 0   It feels a lot like a Disney show instead of a...
# 1   The Weeknd song was too perfect for this trail...
# 2   The most Desi thing about Ms. Marvel was when ...
# 3   Güzel bir diziye benziyor MS Marvel avengers o...
# 4   Kinda bummed they're switching up the powers s...
# 5     It was the better of the marvel shows this year
# 6   No way did we get a Ms Marvel trailer before T...
# 7   Even after watching the series, I still get ve...
# 8   Like most, I think everything is on point here...
# 9             This trailer still gives me the chills.
# 10  It's always fun watching the trailer after you...
# 11  The trailer does this show no justice when i f...
# 12  Can't Believe Marvel actually Remixed Blinding...
# 13  She’s adorable and realistic for a teenage fan...
# 14  Just finished watching it today and I absolute...
# 15  I can’t believe I actually enjoyed this show, ...
# 16  I know I'm late commenting on this, but I am s...
# 17  I’m 35 not really fan of comics and whatnot bu...
# 18  Really looking forward to this. Not sure how m...
# 19  It seems crazy how 70% of the trailer is the f...
# 20  Despite the PG rating and young adult themes, ...
# 21                             I'm loving this series
# 22                 The blinding lights theme though ️
# 23  i loved this comic when i was younger, i can't...
# 24  I’m still a little on the fence about the fact...
# 25  Just watched the first episode and it was sooo...
# 26    It’s actually a pretty good show, I’m impressed
# 27  that show was actually so good! I wasn't expec...
# 28  Her backstory is different so her powers are g...
# 29  This is an excellent marvel series. It has gre...
# 30  I love that they really played into her superh...
# 31  the music is ON POINT\nedit: Its been 4 months...
# 32  Definetely a "homecoming" vibe to it. It looks...
# 33               I'm very much excited for this one ️
# 34  I have Disney Plus so I've seen the 5 minute g...
# 35                    She’s adorable and magnificent.
# 36  This gives me homecoming vibesThe way it shows...
# 37  Absolutely loved the first episode: the aesthe...
# 38  I don’t like the new powers but her personalit...
# 39                           Great Job Marvel Studios
#
#                                              UserLink
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6   https://www.youtube.com/channel/UCmbP8tvKwBWeK...
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18  https://www.youtube.com/channel/UCssW3gaIc8BHu...
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN

# %%
pip install vaderSentiment
# Out:
# Requirement already satisfied: vaderSentiment in c:\users\admin\anaconda3\lib\site-packages (3.3.2)
# Requirement already satisfied: requests in c:\users\admin\anaconda3\lib\site-packages (from vaderSentiment) (2.28.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\admin\anaconda3\lib\site-packages (from requests->vaderSentiment) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\admin\anaconda3\lib\site-packages (from requests->vaderSentiment) (1.26.11)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\admin\anaconda3\lib\site-packages (from requests->vaderSentiment) (2022.9.14)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\admin\anaconda3\lib\site-packages (from requests->vaderSentiment) (3.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

sentiments = SentimentIntensityAnalyzer()
data1["Positive"] = [sentiments.polarity_scores(i)["pos"] for i in data1["Comment"]]
data1["Negative"] = [sentiments.polarity_scores(i)["neg"] for i in data1["Comment"]]
data1["Neutral"] = [sentiments.polarity_scores(i)["neu"] for i in data1["Comment"]]
data1['Compound'] = [sentiments.polarity_scores(i)["compound"] for i in data1["Comment"]]
score = data1["Compound"].values
sentiment = []
for i in score:
    if i >= 0.05 :
        sentiment.append('Positive')
    elif i <= -0.05 :
        sentiment.append('Negative')
    else:
        sentiment.append('Neutral')
data1["Sentiment"] = sentiment
data1.head()
# Out:
#                                              Comment UserLink  Positive  \
# 0  It feels a lot like a Disney show instead of a...      NaN     0.325
# 1  The Weeknd song was too perfect for this trail...      NaN     0.222
# 2  The most Desi thing about Ms. Marvel was when ...      NaN     0.331
# 3  Güzel bir diziye benziyor MS Marvel avengers o...      NaN     0.189
# 4  Kinda bummed they're switching up the powers s...      NaN     0.209
#
#    Negative  Neutral  Compound Sentiment
# 0       0.0    0.675    0.6486  Positive
# 1       0.0    0.778    0.6114  Positive
# 2       0.0    0.669    0.8555  Positive
# 3       0.0    0.811    0.4215  Positive
# 4       0.0    0.791    0.9765  Positive

# %%
data2=data1.drop(['Positive','Negative','Neutral','Compound'],axis=1)
data2.head()
# Out:
#                                              Comment UserLink Sentiment
# 0  It feels a lot like a Disney show instead of a...      NaN  Positive
# 1  The Weeknd song was too perfect for this trail...      NaN  Positive
# 2  The most Desi thing about Ms. Marvel was when ...      NaN  Positive
# 3  Güzel bir diziye benziyor MS Marvel avengers o...      NaN  Positive
# 4  Kinda bummed they're switching up the powers s...      NaN  Positive

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
stop_words = stopwords.words('english')
porter_stemmer = PorterStemmer()
lancaster_stemmer = LancasterStemmer() 
snowball_stemer = SnowballStemmer(language="english")
lzr = WordNetLemmatizer()

# %%
def text_processing(text):   
    # convert text into lowercase
    text = text.lower()

    # remove new line characters in text
    text = re.sub(r'\n',' ', text)
    
    # remove punctuations from text
    text = re.sub('[%s]' % re.escape(punctuation), "", text)
    
    # remove references and hashtags from text
    text = re.sub("^a-zA-Z0-9$,.", "", text)
    
    # remove multiple spaces from text
    text = re.sub(r'\s+', ' ', text, flags=re.I)
    
    # remove special characters from text
    text = re.sub(r'\W', ' ', text)

    text = ' '.join([word for word in word_tokenize(text) if word not in stop_words])
    
    # stemming using porter stemmer from nltk package - msh a7sn 7aga - momken: lancaster, snowball
    # text=' '.join([porter_stemmer.stem(word) for word in word_tokenize(text)])
    # text=' '.join([lancaster_stemmer.stem(word) for word in word_tokenize(text)])
    # text=' '.join([snowball_stemer.stem(word) for word in word_tokenize(text)])
    
    # lemmatizer using WordNetLemmatizer from nltk package
    text=' '.join([lzr.lemmatize(word) for word in word_tokenize(text)])

    return text

# %%
nltk.download('omw-1.4')
data_copy = data2.copy()
# Out:
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %%
processed_data = {
    'Sentence':data_copy.Comment,
    'Sentiment':data_copy['Sentiment']
}

processed_data = pd.DataFrame(processed_data)
processed_data.head()
# Out:
#                                             Sentence Sentiment
# 0  It feels a lot like a Disney show instead of a...  Positive
# 1  The Weeknd song was too perfect for this trail...  Positive
# 2  The most Desi thing about Ms. Marvel was when ...  Positive
# 3  Güzel bir diziye benziyor MS Marvel avengers o...  Positive
# 4  Kinda bummed they're switching up the powers s...  Positive

# %%
processed_data['Sentiment'].value_counts()
# Out:
# Positive    36
# Neutral      2
# Negative     2
# Name: Sentiment, dtype: int64
